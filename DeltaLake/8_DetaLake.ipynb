# %% [markdown]
# # UNIFORM

# %%
# %sql
CREATE TABLE deltalakecesar.default.unitbl 
USING DELTA TBLPROPERTIES(
  'delta.enableIcebergCompatV2' = 'true',
  'delta.universalFormat.enableFormats' = 'iceberg');

# %%
# %sql
CREATE TABLE deltalakecesar.default.unitbl 
USING DELTA TBLPROPERTIES(
  'delta.enableIcebergCompatV2' = 'true',
  'delta.universalFormat.enableFormats' = 'iceberg');

# %%
# %sql
INSERT INTO deltalakecesar.default.unitbl
